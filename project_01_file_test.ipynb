# %% [markdown]
# # Bitcoin Historical Data
# * [https://www.kaggle.com/mczielinski/bitcoin-historical-data](https://www.kaggle.com/mczielinski/bitcoin-historical-data)

# %%
import pandas as pd
import time
    
string = time.strftime("%Y/%m/%d %H:%M:%S", time.localtime(1234567890))
string
# Out:
# '2009/02/14 08:31:30'

# %%
df = pd.read_csv('bitstampUSD_1-min_data.csv')
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df = df.dropna()
df.astype({'Timestamp': 'int64'})
df.index = [i for i in range(len(df))]
pd.options.mode.chained_assignment = None
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581           2.000000
# 1  1325346600  4.39  4.39  4.39   4.39     48.000000         210.720000
# 2  1325350740  4.50  4.57  4.50   4.57     37.862297         171.380338
# 3  1325350800  4.58  4.58  4.58   4.58      9.000000          41.220000
# 4  1325391360  4.58  4.58  4.58   4.58      1.502000           6.879160
#
#    Weighted_Price
# 0        4.390000
# 1        4.390000
# 2        4.526411
# 3        4.580000
# 4        4.580000

# %%
timestamp = df['Timestamp']
stamps = []
for j in range(len(timestamp)):
    stamp = time.strftime("%Y/%m/%d %H:%M:%S", time.localtime(timestamp[j].item()))
    stamps.append(stamp)

# %%
df['Timestamp'] = stamps
df.head()
# Out:
#              Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0  2011/12/31 16:52:00  4.39  4.39  4.39   4.39      0.455581
# 1  2012/01/01 00:50:00  4.39  4.39  4.39   4.39     48.000000
# 2  2012/01/01 01:59:00  4.50  4.57  4.50   4.57     37.862297
# 3  2012/01/01 02:00:00  4.58  4.58  4.58   4.58      9.000000
# 4  2012/01/01 13:16:00  4.58  4.58  4.58   4.58      1.502000
#
#    Volume_(Currency)  Weighted_Price
# 0           2.000000        4.390000
# 1         210.720000        4.390000
# 2         171.380338        4.526411
# 3          41.220000        4.580000
# 4           6.879160        4.580000

# %%
df.to_csv('project_01_df2.csv')

# %%
doc = pd.read_csv('project_01_df2.csv', encoding='utf-8-sig')
doc.head()
# Out:
#    Unnamed: 0            Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0           0  2011/12/31 16:52:00  4.39  4.39  4.39   4.39      0.455581
# 1           1  2012/01/01 00:50:00  4.39  4.39  4.39   4.39     48.000000
# 2           2  2012/01/01 01:59:00  4.50  4.57  4.50   4.57     37.862297
# 3           3  2012/01/01 02:00:00  4.58  4.58  4.58   4.58      9.000000
# 4           4  2012/01/01 13:16:00  4.58  4.58  4.58   4.58      1.502000
#
#    Volume_(Currency)  Weighted_Price
# 0           2.000000        4.390000
# 1         210.720000        4.390000
# 2         171.380338        4.526411
# 3          41.220000        4.580000
# 4           6.879160        4.580000

# %%
del doc['Unnamed: 0']
doc.head()
# Out:
#              Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0  2011/12/31 16:52:00  4.39  4.39  4.39   4.39      0.455581
# 1  2012/01/01 00:50:00  4.39  4.39  4.39   4.39     48.000000
# 2  2012/01/01 01:59:00  4.50  4.57  4.50   4.57     37.862297
# 3  2012/01/01 02:00:00  4.58  4.58  4.58   4.58      9.000000
# 4  2012/01/01 13:16:00  4.58  4.58  4.58   4.58      1.502000
#
#    Volume_(Currency)  Weighted_Price
# 0           2.000000        4.390000
# 1         210.720000        4.390000
# 2         171.380338        4.526411
# 3          41.220000        4.580000
# 4           6.879160        4.580000

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
doc.head()
# Out:
#              Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0  2011/12/31 16:52:00  4.39  4.39  4.39   4.39      0.455581
# 1  2012/01/01 00:50:00  4.39  4.39  4.39   4.39     48.000000
# 2  2012/01/01 01:59:00  4.50  4.57  4.50   4.57     37.862297
# 3  2012/01/01 02:00:00  4.58  4.58  4.58   4.58      9.000000
# 4  2012/01/01 13:16:00  4.58  4.58  4.58   4.58      1.502000
#
#    Volume_(Currency)  Weighted_Price
# 0           2.000000        4.390000
# 1         210.720000        4.390000
# 2         171.380338        4.526411
# 3          41.220000        4.580000
# 4           6.879160        4.580000

# %%
doc['Timestamp'] = pd.to_datetime(doc['Timestamp'])
print(type(doc['Timestamp'][0]))
doc = doc.set_index('Timestamp')
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
doc_open = doc[['Open']]
doc_high = doc[['High']]
doc_low = doc[['Low']]
doc_close = doc[['Close']]


doc_open.plot()
doc_high.plot()
doc_low.plot()
doc_close.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
doc_all = doc[['Open', 'High', 'Low', 'Close']]
doc_all.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
doc.describe()
# Out:
#                Open          High           Low         Close  Volume_(BTC)  \
# count  3.484305e+06  3.484305e+06  3.484305e+06  3.484305e+06  3.484305e+06
# mean   4.570658e+03  4.573721e+03  4.567413e+03  4.570624e+03  9.422676e+00
# std    4.775105e+03  4.778620e+03  4.771352e+03  4.775094e+03  3.101255e+01
# min    3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00  0.000000e+00
# 25%    4.321900e+02  4.324300e+02  4.320000e+02  4.322000e+02  3.917811e-01
# 50%    3.085010e+03  3.093250e+03  3.078010e+03  3.084410e+03  1.936719e+00
# 75%    8.158010e+03  8.162850e+03  8.152790e+03  8.157310e+03  7.299825e+00
# max    2.899738e+04  2.901032e+04  2.896366e+04  2.899738e+04  5.853852e+03
#
#        Volume_(Currency)  Weighted_Price
# count       3.484305e+06    3.484305e+06
# mean        3.315691e+04    4.570625e+03
# std         1.129107e+05    4.775090e+03
# min         0.000000e+00    3.800000e+00
# 25%         4.147936e+02    4.321753e+02
# ...

# %%
doc.head(20)
# Out:
#                      Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# Timestamp
# 2011-12-31 16:52:00  4.39  4.39  4.39   4.39      0.455581           2.000000
# 2012-01-01 00:50:00  4.39  4.39  4.39   4.39     48.000000         210.720000
# 2012-01-01 01:59:00  4.50  4.57  4.50   4.57     37.862297         171.380338
# 2012-01-01 02:00:00  4.58  4.58  4.58   4.58      9.000000          41.220000
# 2012-01-01 13:16:00  4.58  4.58  4.58   4.58      1.502000           6.879160
# 2012-01-02 00:28:00  4.84  4.84  4.84   4.84     10.000000          48.400000
# 2012-01-02 07:45:00  5.00  5.00  5.00   5.00     10.100000          50.500000
# 2012-01-03 05:04:00  5.00  5.00  5.00   5.00     19.048000          95.240000
# 2012-01-03 20:45:00  5.32  5.32  5.32   5.32      2.419173          12.870000
# 2012-01-03 23:22:00  5.14  5.14  5.14   5.14      0.680000           3.495200
# 2012-01-03 23:54:00  5.26  5.26  5.26   5.26     29.319392         154.220000
# ...
